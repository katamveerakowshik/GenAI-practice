# %%
from langchain_community.document_loaders import TextLoader
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOllama(model="llama3.2:latest")
template = PromptTemplate(
    template = "Please summarise the given poem - /n {poem} ",
    input_variables = ["poem"])
parser = StrOutputParser()

# %%
#Using text loader to load the text
loader = TextLoader("cricket_poem.txt")
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'cricket_poem.txt'}, page_content='On a square of dust and emerald green,\nWhere willow meets a leathered dream,\nThe pitch lies patient, scored and worn,\nAwaiting duels each gentle morn.\n\nThe bowler runs with thundered breath,\nA measured dance with speed and death,\nThe ball swings late, a whispered plea,\nTo bend the laws of gravity.\n\nThe batter stands, a quiet flame,\nEyes alight with timingâ€™s game,\nOne perfect stroke, a crack, a sighâ€”\nThe ball writes arcs across the sky.\n\nApplause rolls like summer rain,\nFor loss and glory share the same plane,\nA nick, a catch, a shattered stump,\nHearts rise, then fall, then wildly jump.\n\nFrom gullyâ€™s crouch to boundaryâ€™s chase,\nEleven souls, one shared embrace,\nIn whites or colors, day or night,\nCricket stitches time to light.\n\nFor more than runs or numbers told,\nItâ€™s patience learned and courage bold,\nA game where silence speaks the mostâ€”\nAnd every match becomes a ghost.')]

# %%
#Docs is list but docs[0] is a document object
type(docs)
# Out:
# list

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
docs[0]
# Out:
# Document(metadata={'source': 'cricket_poem.txt'}, page_content='On a square of dust and emerald green,\nWhere willow meets a leathered dream,\nThe pitch lies patient, scored and worn,\nAwaiting duels each gentle morn.\n\nThe bowler runs with thundered breath,\nA measured dance with speed and death,\nThe ball swings late, a whispered plea,\nTo bend the laws of gravity.\n\nThe batter stands, a quiet flame,\nEyes alight with timingâ€™s game,\nOne perfect stroke, a crack, a sighâ€”\nThe ball writes arcs across the sky.\n\nApplause rolls like summer rain,\nFor loss and glory share the same plane,\nA nick, a catch, a shattered stump,\nHearts rise, then fall, then wildly jump.\n\nFrom gullyâ€™s crouch to boundaryâ€™s chase,\nEleven souls, one shared embrace,\nIn whites or colors, day or night,\nCricket stitches time to light.\n\nFor more than runs or numbers told,\nItâ€™s patience learned and courage bold,\nA game where silence speaks the mostâ€”\nAnd every match becomes a ghost.')

# %%
docs[0].page_content
# Out:
# 'On a square of dust and emerald green,\nWhere willow meets a leathered dream,\nThe pitch lies patient, scored and worn,\nAwaiting duels each gentle morn.\n\nThe bowler runs with thundered breath,\nA measured dance with speed and death,\nThe ball swings late, a whispered plea,\nTo bend the laws of gravity.\n\nThe batter stands, a quiet flame,\nEyes alight with timingâ€™s game,\nOne perfect stroke, a crack, a sighâ€”\nThe ball writes arcs across the sky.\n\nApplause rolls like summer rain,\nFor loss and glory share the same plane,\nA nick, a catch, a shattered stump,\nHearts rise, then fall, then wildly jump.\n\nFrom gullyâ€™s crouch to boundaryâ€™s chase,\nEleven souls, one shared embrace,\nIn whites or colors, day or night,\nCricket stitches time to light.\n\nFor more than runs or numbers told,\nItâ€™s patience learned and courage bold,\nA game where silence speaks the mostâ€”\nAnd every match becomes a ghost.'

# %%
chain = template | llm | parser

# %%
chain.invoke(docs[0].page_content)
# Out:
# "The poem is about the game of cricket. It describes the scene of the game, with the bowler, batter, and other players, as well as the anticipation and excitement of the crowd. The poem highlights the patience, courage, and skill required to play the game, as well as the emotional highs and lows that come with it.\n\nThe poem also touches on the idea that cricket is more than just a game - it's a way of life, a connection between people, and a way to stitch time together. The speaker suggests that the silence of the game can speak louder than words, and that every match becomes a memorable experience that lingers long after it's over.\n\nOverall, the poem is a tribute to the beauty and emotional depth of cricket, and invites the reader to appreciate its unique spirit and tradition."

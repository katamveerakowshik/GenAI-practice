# %%
from langchain_ollama import ChatOllama
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, Sequence, List, Dict, Any
import operator
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage, SystemMessage

# %%
llm = ChatOllama(model="llama3.2")

# %%
class AgentState(TypedDict):
    messages: Annotated[List[BaseMessage], operator.add]
    task: str
    plan: str
    critique: str

# %%
def researcher_node(state:AgentState):
    prompt = ("Role: Researcher. Propose 3 concise facts or sources to inform the solution. "
        "Output as bullet points. Do not provide a final answer.")    
    
    response = llm.invoke([SystemMessage(content=prompt), HumanMessage(content=state['task'])])
    return {"messages": [response]}

def planner_node(state:AgentState):
    is_revison = len(state.get("critique", "")) > 0
    role_instruction = "Role: Planner. Propose a ordered plan (3-5 steps) to solve the task."
    if is_revison:
        role_instruction += f"Revise the plan based on the critique provided. {state['critique']}"
    
    response = llm.invoke(
        [SystemMessage(content=role_instruction)] + state['messages'])
    return {"messages": [response], "plan": response.content}

def critic_node(state:AgentState):
    prompt = ("Role: Critic. Review the plan for gaps, conflicts or missing data. "
        "Return 2-3 actionable improvements.")
    
    response = llm.invoke(
        [SystemMessage(content=prompt)] + state['messages'])
    return {"messages": [response], "critique": response.content}

# %%
workflow = StateGraph(AgentState)

workflow.add_node("researcher", researcher_node)
workflow.add_node("planner", planner_node)
workflow.add_node("critic", critic_node)
workflow.add_node("reviser", planner_node)

# %%
workflow.set_entry_point("researcher")
workflow.add_edge("researcher", "planner")
workflow.add_edge("planner", "critic")
workflow.add_edge("critic", "reviser")
workflow.add_edge("reviser", END)

app = workflow.compile()

# %%
TASK = "Design a 3-email outreach sequence for a B2B AI tool targeting healthcare analytics leaders. Include subject lines and a clear CTA each."

inputs = {"task": TASK, "messages": [HumanMessage(content=TASK)], "plan": "", "critique": ""}

print("--- STARTING MULTI-AGENT RUN ---")
for output in app.stream(inputs):
    for node_name, state_update in output.items():
        print(f"\n[Node: {node_name.upper()}]")
        if "messages" in state_update:
            print(state_update["messages"][-1].content)
# Out:
# --- STARTING MULTI-AGENT RUN ---
#
# [Node: RESEARCHER]
# Here are three possible email sequences:
#
# **Email 1: Introduction and Awareness (Subject Line: "Unlock the Power of AI in Healthcare Analytics")**
#
# * Email Body:
# 	+ Introduce the AI tool and its benefits for healthcare analytics
# 	+ Highlight key statistics on the importance of data-driven decision making in healthcare
# 	+ Provide a brief overview of the upcoming email sequence
# * CTA: "Get Instant Access to Our Free Whitepaper" (whitepaper will be sent via attachment or embedded in the email)
# * Goal: Raise awareness and generate interest among the recipient
#
# **Email 2: Problem-Agitate-Solve (Subject Line: "Are You Struggling with Data Quality in Your Analytics Team?")**
#
# * Email Body:
# 	+ Identify a common pain point faced by healthcare analytics leaders (e.g. data quality issues)
# 	+ Agitate the problem by highlighting its consequences (e.g. delayed insights, incorrect decisions)
# 	+ Introduce the AI tool as a solution to address this issue
# * CTA: "Schedule a Demo to See How Our Tool Can Help" (demo will be sent via calendar invite or link in the email)
# * Goal: Agitate the problem and position the AI tool as a potential solution
#
# **Email 3: Value Proposition and Next Steps (Subject Line: "Maximize Your ROI with AI-Powered Insights")**
#
# * Email Body:
# 	+ Highlight the benefits of using the AI tool for healthcare analytics (e.g. improved accuracy, faster insights)
# 	+ Share success stories or case studies from existing clients
# 	+ Encourage the recipient to take action and explore further options
# * CTA: "Get a Personalized Consultation to Discuss Your Analytics Goals" (consultation will be scheduled via phone call or video meeting)
# * Goal: Close the deal by providing value and moving the recipient towards purchasing the AI tool
#
# [Node: PLANNER]
#
#
# Note that each email should be tailored to the specific needs and interests of the recipient, and the CTAs should be clear and actionable.
#
# [Node: CRITIC]
#
#
# [Node: REVISER]
# This sequence is just a suggestion, you can adjust it according to your needs and the preferences of your audience.

# %%
final_state = app.invoke(inputs)

print("\n--- FINAL STATE ---")
print("Task:", final_state["task"])
print("Plan:", final_state["plan"])
print("Critique:", final_state["critique"])
print("Messages count:", len(final_state["messages"]))
# Out:
# --- FINAL STATE ---
# Task: Design a 3-email outreach sequence for a B2B AI tool targeting healthcare analytics leaders. Include subject lines and a clear CTA each.
# Plan: Each email is designed to be concise, clear, and relevant to the recipient's interests and pain points. The CTAs are also well-structured to encourage a response or action from the recipient.
#
# Feel free to customize these examples to fit your specific brand voice and messaging!
# Critique:
# Messages count: 5

# %%
final_state["messages"]
# Out:
# [HumanMessage(content='Design a 3-email outreach sequence for a B2B AI tool targeting healthcare analytics leaders. Include subject lines and a clear CTA each.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Here are three possible email outreach sequences:\n\n**Email 1: Introduction and Awareness**\n\nSubject Line: "Unlock the Power of Data-Driven Decision Making in Healthcare"\n\n* Brief introduction to the company and its B2B AI tool\n* Highlighting the importance of data analytics in healthcare decision making\n* Request for permission to connect with the recipient\'s organization\n\nExample email:\n\nDear [Recipient\'s Name],\n\nI came across your profile as a leader in the healthcare analytics space, and I\'d like to introduce you to our innovative B2B AI tool designed to help organizations like yours make data-driven decisions.\n\nOur solution leverages machine learning algorithms to analyze vast amounts of healthcare data, identifying trends, patterns, and insights that inform strategic decision making.\n\nWould you be open to a brief call to discuss how our technology can address specific pain points in your organization?\n\nBest regards,\n[Your Name]\n\n**Email 2: Value Proposition and Benefits**\n\nSubject Line: "Boost Efficiency and Accuracy with Our AI-Powered Analytics Tool"\n\n* Detailed overview of the tool\'s features and benefits\n* Highlighting case studies or success stories from similar industries\n* Emphasis on how the solution can drive business value\n\nExample email:\n\nHi [Recipient\'s Name],\n\nAs a healthcare analytics leader, you understand the importance of efficient decision making. Our B2B AI tool is designed to help organizations like yours streamline their analytics processes, reducing manual effort and increasing accuracy.\n\nOur solution has already helped similar industries in the life sciences sector improve patient outcomes, reduce costs, and enhance operational efficiency.\n\nWould you be interested in learning more about how our technology can address specific pain points in your organization?\n\nBest regards,\n[Your Name]\n\n**Email 3: Invitation to Demo or Trial**\n\nSubject Line: "Experience the Power of Our AI-Powered Analytics Tool for Yourself"\n\n* Personalized invitation to schedule a demo or trial\n* Emphasis on hands-on experience with the solution\n* Clear call-to-action (CTA) for scheduling a meeting\n\nExample email:\n\nHi [Recipient\'s Name],\n\nI hope our previous discussions have piqued your interest in our B2B AI tool. We\'d love to invite you to schedule a demo or trial, where you can experience the power of our technology firsthand.\n\nOur team will work closely with you to understand your specific use cases and provide personalized guidance on how to get the most out of our solution.\n\nWould you be available for a 30-minute meeting next week?', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-01-24T14:24:14.9307279Z', 'done': True, 'done_reason': 'stop', 'total_duration': 55577500600, 'load_duration': 556741900, 'prompt_eval_count': 84, 'prompt_eval_duration': 138694300, 'eval_count': 497, 'eval_duration': 53125327100, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019bf063-5110-7c32-84fd-fc510b7530d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 84, 'output_tokens': 497, 'total_tokens': 581}),
#  AIMessage(content=" I'd be happy to schedule it at your convenience.\n\nBest regards,\n[Your Name]\n\nThis email sequence aims to build awareness, educate, and invite the recipient to experience the value proposition of the B2B AI tool.", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-01-24T14:24:47.7717443Z', 'done': True, 'done_reason': 'stop', 'total_duration': 32781935400, 'load_duration': 384019500, 'prompt_eval_count': 570, 'prompt_eval_duration': 27488434900, 'eval_count': 46, 'eval_duration': 4501992900, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019bf064-2a87-72a0-a0e2-4f8cf6f53098-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 570, 'output_tokens': 46, 'total_tokens': 616}),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-01-24T14:25:17.3064446Z', 'done': True, 'done_reason': 'stop', 'total_duration': 29528452700, 'load_duration': 326801000, 'prompt_eval_count': 619, 'prompt_eval_duration': 29172689000, 'eval_count': 1, 'eval_duration': None, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019bf064-aaa0-71d2-b421-10ef8fc266af-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 619, 'output_tokens': 1, 'total_tokens': 620}),
#  AIMessage(content="Each email is designed to be concise, clear, and relevant to the recipient's interests and pain points. The CTAs are also well-structured to encourage a response or action from the recipient.\n\nFeel free to customize these examples to fit your specific brand voice and messaging!", additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2026-01-24T14:25:52.7601027Z', 'done': True, 'done_reason': 'stop', 'total_duration': 35447616600, 'load_duration': 326361100, 'prompt_eval_count': 615, 'prompt_eval_duration': 29081698800, 'eval_count': 55, 'eval_duration': 5765984200, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'}, id='lc_run--019bf065-1dff-7770-9698-a79516987d41-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 615, 'output_tokens': 55, 'total_tokens': 670})]

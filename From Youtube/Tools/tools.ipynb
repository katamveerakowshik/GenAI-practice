# %% [markdown]
# ## Built-in Tools

# %%
from langchain_community.tools import DuckDuckGoSearchRun

# %%
search = DuckDuckGoSearchRun()
result = search.invoke("What's happened to Zimbabwe Vs Ireand cricket match today?")
# Out:
# Impersonate 'safari_15.5' does not exist, using 'random'

# %%
print(result)
# Out:
# 3 hours ago · 12 pm GMT - MATCH CALLED OFF! It does seem that way. The umpires have had a word with the groundstaff and now, are going to talk to the two captains. Yes, it ... 1 hour ago · Ireland vs Zimbabwe T20 World Cup Highlights: Relentless rain has led to the Ireland-Zimbabwe clash being called off, a result that knocks Australia out of ... 5 hours ago · MATCH ABANDONED - ZIMBABWE PROGRESS That's it! No play possible in Kandy and it means Zimbabwe secure a place in the Super 8s while Ireland and Australia are ... 2 hours ago · They then spoke to the two captains, and after a brief handshake, the match was officially abandoned. advertisement. Feb 17, 2026 17:27 IST. T20 World Cup live ... 4 hours ago · UPDATE The second T20I between Ireland and England was abandoned due to rain. 🌧️ #Cricket #T20I #England #Ireland.

# %%
from langchain_community.tools.yahoo_finance_news import YahooFinanceNewsTool
finance_news = YahooFinanceNewsTool()
result = finance_news.invoke("AAPL")

# %%
print(result) #result
# Out:
# Apple (AAPL) Underweight Position Weighs on Relative Performance of Sands Capital Technology Innovators Fund
# Sands Capital Management, LLC‘s Technology Innovators Fund released its Q4 2025 investor letter for “Technology Innovators Fund”. A copy of the letter can be downloaded here. The Fund delivered mixed performance during the fourth quarter of 2025, as market returns were increasingly driven by a narrow group of large-cap growth stocks, with the portfolio’s top […]

# %% [markdown]
# ## Custom Tools

# %% [markdown]
# ### Using Decorator

# %%
from langchain_core.tools.Tool import tool


@tool
def multiply(a: int, b: int) -> int:
    """Multiplies two numbers."""
    return a * b

result = multiply.invoke(3, 4)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from langchain_core.tools.Tool import tool
#       4 @tool
#       5 def multiply(a: int, b: int) -> int:
#       6     """Multiplies two numbers."""
#
# ModuleNotFoundError: No module named 'langchain_core.tools.Tool'

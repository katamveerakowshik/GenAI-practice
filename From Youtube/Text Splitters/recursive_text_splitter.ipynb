# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = """On a square of dust and emerald green,
Where willow meets a leathered dream,
The pitch lies patient, scored and worn,
Awaiting duels each gentle morn.

The bowler runs with thundered breath,
A measured dance with speed and death,
The ball swings late, a whispered plea,
To bend the laws of gravity."""

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 30,
    chunk_overlap = 0

)

# %%
chunk = splitter.split_text(text)

# %%
chunk
# Out:
# ['On a square of dust and',
#  'emerald green,',
#  'Where willow meets a',
#  'leathered dream,',
#  'The pitch lies patient,',
#  'scored and worn,',
#  'Awaiting duels each gentle',
#  'morn.',
#  'The bowler runs with',
#  'thundered breath,',
#  'A measured dance with speed',
#  'and death,',
#  'The ball swings late, a',
#  'whispered plea,',
#  'To bend the laws of gravity.']

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language

# %%
text = """
class PromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables
    
    def invoke(self, input_dict):
        return self.template.format(**input_dict)

    def format(self, input_dict):
        return self.template.format(**input_dict)

template = PromptTemplate(
template = "What is the current news about {topic}?",
input_variables = ["topic"])

llm = LLM()
str_output_parser = StrIOutputParser()
"""

# %%
splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.PYTHON,
    chunk_size = 300,
    chunk_overlap = 0
)

# %%
# Use split documents while splitting documents instead of text
chunks = splitter.split_text(text)

# %%
chunks
# Out:
# ['class PromptTemplate:\n    def __init__(self, template, input_variables):\n        self.template = template\n        self.input_variables = input_variables\n\n    def invoke(self, input_dict):\n        return self.template.format(**input_dict)',
#  'def format(self, input_dict):\n        return self.template.format(**input_dict)\n\ntemplate = PromptTemplate(\ntemplate = "What is the current news about {topic}?",\ninput_variables = ["topic"])\n\nllm = LLM()\nstr_output_parser = StrIOutputParser()']

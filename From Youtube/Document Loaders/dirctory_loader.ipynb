# %%
from langchain_ollama import ChatOllama
from langchain_community.document_loaders import DirectoryLoader, TextLoader

# %%
loader = DirectoryLoader(
    path = "books",
    glob = "*.txt",
    loader_cls = TextLoader,
)

# %%
docs = loader.load()

# %%
len(docs)
# Out:
# 2

# %%
docs[1].page_content
# Out:
# 'On Valentineâ€™s Day, the world turns red,\nWith whispered hopes and words unsaid.\nHearts beat louder, shy yet brave,\nFor love is the gift we dare to give.\n\nA note, a smile, a gentle touch,\nSmall things that mean so very much.\nIn quiet glances, hands entwined,\nTwo souls agree to slow down time.\n\nNot all love comes wrapped in rose,\nIt lives where kindness softly growsâ€”\nIn friendships warm, in care so true,\nIn loving others as we do you.\n\nSo let this day remind us all,\nWhen petals fade and chocolates fall,\nThat love, when real, needs no displayâ€”\nIt lives in how we choose each day.'
